# %%
cd /Users/chenyunqing/Documents
# Out:
# /Users/chenyunqing/Documents

# %%
! git clone https://github.com/YunqingIvyChen/qtm350-quiz01.git
# Out:
# Cloning into 'qtm350-quiz01'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 8 (delta 0), reused 8 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (8/8), done.

# %%
cd /Users/chenyunqing/Documents/qtm350-quiz01
# Out:
# /Users/chenyunqing/Documents/qtm350-quiz01
